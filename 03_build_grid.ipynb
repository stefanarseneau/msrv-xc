# %%
import msrvxc

import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
wl_grid, raw_bosz, interp_bosz, interp_bosz_norm = msrvxc.build.build_bosz_grid(R_target = 4000)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# https://archive.stsci.edu/missions/hlsp/bosz/fits/insbroad_010000/metal_+0.00/carbon_+0.00/alpha_+0.00/amp00cp00op00t10000g20v20modrt0b10000rs.fits
#   7%|▋         | 1/15 [00:13<03:07, 13.37s/it]
# [!!ERR] Could not find file: https://archive.stsci.edu/missions/hlsp/bosz/fits/insbroad_010000/metal_-2.50/carbon_+0.00/alpha_+0.00/amm25cp00op00t3500g35v20modrt0b10000rs.fits
# [!!ERR] Could not find file: https://archive.stsci.edu/missions/hlsp/bosz/fits/insbroad_010000/metal_-2.50/carbon_+0.00/alpha_+0.00/amm25cp00op00t3500g40v20modrt0b10000rs.fits
# [!!ERR] Could not find file: https://archive.stsci.edu/missions/hlsp/bosz/fits/insbroad_010000/metal_-2.50/carbon_+0.00/alpha_+0.00/amm25cp00op00t3500g45v20modrt0b10000rs.fits
# [!!ERR] Could not find file: https://archive.stsci.edu/missions/hlsp/bosz/fits/insbroad_010000/metal_-2.50/carbon_+0.00/alpha_+0.00/amm25cp00op00t3500g50v20modrt0b10000rs.fits
# ...

# %%
plt.plot(wl_grid, interp_bosz_norm((3500, 3, -1)))

# %%
with open('grids/interp_bosz_norm.pickle', 'wb') as handle:
    pickle.dump(interp_bosz_norm, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
np.save('grids/wavl.npy', wl_grid)
